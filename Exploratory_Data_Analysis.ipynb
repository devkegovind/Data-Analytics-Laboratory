# %% [markdown]
# <h1 align='center'><b>TO PERFORM EXPLORATORY DATA ANALYSIS ON AUTOMOBILE DATA</b></h1>

# %% [markdown]
# <h4><b>Theory:</b></h4>
#
# <h4><b>What is Exploratory Data Analysis?</b></h4>
#
# <h4 align='justify'>Exploratory Data Analysis (EDA) is an approach to analyze the data using visual techniques.
# It is used to discover trends, patterns, or to check assumptions with the help of statistical
# summary and graphical representations.
# An EDA is a thorough examination meant to uncover the underlying structure of a data set and is
# important for a company because it exposes trends, patterns, and relationships that are not
# readily apparent.</h4>
#
# <h4><b>What are the types of exploratory data analysis?</b></h4>
# <h4 align='justify'>The four types of EDA are</h4>
#
# 1. univariate non-graphical,
# 2. multivariate non- graphical,
# 3. univariate graphical,
# 4. multivariate graphical.
#
#
# <h4><b>Techniques and Tools:</b></h4>
# <h4 align='justify'>There are a number of tools that are useful for EDA, but EDA is characterized more by the
# attitude taken than by particular techniques.
# Typical graphical techniques used in EDA are:</h4>
#
# - Box plot
# - Histogram
# - Multi-vari chart
# - Run chart
# - Pareto chart
# - Scatter plot (2D/3D)
# - Stem-and-leaf plot
# - Parallel coordinates
# - Odds ratio
# - Heat map
# - Bar chart
# - Horizon graph
# - Dimensionality reduction:
# - Multidimensional scaling
# - Principal component analysis (PCA)
# - Multilinear PCA
# - Iconography of correlations
#
# <h4><b>Non-Graphical Exploratory Data Analysis</b></h4>
# <h4 align='justify'>Non-graphical exploratory data analysis is the first step when beginning to analyze your data as
# part of the general data analysis approach.</h4>
# <h4><b>Measures of central tendency</b></h4>
# <h4 align='justify'>i.e. the mean, the media and mode
# <h4><b>Measures of spread</b></h4>
# <h4 align='justify'>i.e. variability, variants and standard deviation, the shape of the distribution, and the existence of
# outliers.</h4>
# <h4><b>Conclusion:</b></h4>
# <h4 align='justify'>Analysis of the data set provides</h4>
#
# - How the data set are distributed
# - Correlation between different fields and how they are related
# - Normalized loss of the manufacturer
# - Mileage : Mileage based on City and Highway driving for various make and attributes
# - Price : Factors affecting Price of the Automobile.
# - Importance of drive wheels and curb weight

# %% [markdown]
# <h4 align='justify'><b>Import Library</b></h4>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h4 align='justify'><b>Data Loading</b></h4>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/DAL/automobileEDA.csv')
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.tail()
# Out:
#      symboling  normalized-losses   make aspiration num-of-doors body-style  \
# 196         -1                 95  volvo        std         four      sedan
# 197         -1                 95  volvo      turbo         four      sedan
# 198         -1                 95  volvo        std         four      sedan
# 199         -1                 95  volvo      turbo         four      sedan
# 200         -1                 95  volvo      turbo         four      sedan
#
#     drive-wheels engine-location  wheel-base    length  ...  \
# 196          rwd           front       109.1  0.907256  ...
# 197          rwd           front       109.1  0.907256  ...
# 198          rwd           front       109.1  0.907256  ...
# 199          rwd           front       109.1  0.907256  ...
# 200          rwd           front       109.1  0.907256  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.sample(5)
# Out:
#      symboling  normalized-losses           make aspiration num-of-doors  \
# 67          -1                 93  mercedes-benz      turbo         four
# 118          1                154       plymouth        std         four
# 8            1                158           audi      turbo         four
# 157          0                 91         toyota        std         four
# 46           0                122         jaguar        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 67       sedan          rwd           front       115.6  0.973570  ...
# 118      sedan          fwd           front        93.7  0.803940  ...
# 8        sedan          fwd           front       105.8  0.925997  ...
# 157  hatchback          fwd           front        95.7  0.799135  ...
# 46       sedan          rwd           front       102.0  0.921192  ...
#
#      compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.shape
# Out:
# (201, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %% [markdown]
# <h4 align='justify'><b>Data Cleaning</b></h4>

# %%
df = df.replace("?", np.NAN)

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    1
# diesel               0
# gas                  0
# dtype: int64

# %%
df['stroke'].fillna('np.nan', inplace = True)

# %%
df['horsepower-binned'].fillna('np.nan', inplace = True)

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
df.head(10)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
# 5          2                122         audi        std          two
# 6          1                158         audi        std         four
# 7          1                122         audi        std         four
# 8          1                158         audi      turbo         four
# 9          2                192          bmw        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# ...

# %% [markdown]
# <h4 align='justify'><b>Summary Statistics of Variable</b></h4>

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore  compression-ratio  \
# count  201.000000   201.000000   201.000000  201.000000         201.000000
# mean    53.766667  2555.666667   126.875622    3.330692          10.164279
# std      2.447822   517.296727    41.546834    0.268072           4.004965
# ...

# %% [markdown]
# <h4><b>Univariate Analysis</b></h4>

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
plt.figure(figsize=(20,15))
df[['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
       'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
       'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
       'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
       'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
       'city-L/100km', 'horsepower-binned', 'diesel', 'gas']].hist(figsize=(20,15), color="G")
plt.figure(figsize=(20,15))
plt.tight_layout()
plt.show()
# hist plot is applicable for only int/float data type of the columns.
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/hist.py:464: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   ax.hist(data[col].dropna().values, bins=bins, **kwds)

# %%
plt.figure(1)
plt.subplot(221)
df['engine-type'].value_counts(normalize=True).plot(figsize=(10,8), kind='bar', color='red')
plt.title("Number of Engine Type Frequency Diagram")
plt.xlabel("Engine-Type")
plt.ylabel("Number of Engine Type")
plt.tight_layout()


plt.subplot(222)
df['num-of-doors'].value_counts(normalize=True).plot(figsize=(10,8), kind='bar', color='green')
plt.title("Number of Doors Frequency Diagram")
plt.xlabel("Number-of-Doors")
plt.ylabel("Number of Doors")
plt.tight_layout()


plt.subplot(224)
df['body-style'].value_counts(normalize=True).plot(figsize=(10,8), kind='bar', color='yellow')
plt.title("Number of Body Style Frequency Diagram")
plt.xlabel("Body Style")
plt.ylabel("Number of Body Style")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4><b>Multivariate Analysis</b></h4>

# %%
corr = df.corr()
plt.figure(figsize=(20,15))
a = sns.heatmap(corr, cmap='brg', annot = True, fmt = '0.2f')

# %% [markdown]
# <h4><b>Bivariate Analysis</b></h4>

# %%
plt.rcParams['figure.figsize']=(20,15)
ax = sns.boxplot(x='make', y='price', data = df)

# %%
plt.rcParams['figure.figsize']=(20,10)
ax = sns.boxplot(x='body-style', y='price', data = df)

# %% [markdown]
# <h4><b>Positive Linear Relationship</b></h4>

# %%
plt.rcParams['figure.figsize']=(20,15)
ax = sns.boxplot(x='drive-wheels', y='price', data = df)

# %%
sns.regplot(x='engine-size', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 53261.41584153652)

# %%
df[['engine-size', 'price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 48175.18458982791)

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x='peak-rpm', y='price', data=df)
plt.show()

# %%
df[['peak-rpm', 'price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
sns.barplot(x='body-style', y='price', data=df)
plt.show()

# %%
sns.barplot(x='engine-location', y='price', data=df)
plt.show()

# %%
sns.violinplot(x='drive-wheels', y='price', data=df)
plt.show()
